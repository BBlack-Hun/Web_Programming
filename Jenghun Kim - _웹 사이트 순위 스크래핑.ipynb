# %% [markdown]
# # BeautyfulSoup 웹 사이트 순위 스크래핑
#
# * Alexa: https://www.alexa.com/topsites

# %%
from bs4 import  BeautifulSoup
import urllib.request
import pandas as pd

url = "https://www.alexa.com/topsites"
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url, 'html.parser')
rank_df = pd.DataFrame(columns=("Rank", "Site", "Daily Time on Site", "Daily Pageviews per Visitor", "% of Traffic From Search", "Total Sites Linking In"))

sites = soup.find_all('div', {'class':'tr site-listing'})

for site in sites:
  rank = site.find('div', {'class': 'td'}).get_text()
  website = site.select('p > a')[0].get_text()
  infos = site.find_all('div', {'class': 'td right'})
  time = infos[0].get_text()
  pageview = infos[1].get_text()
  traffic = infos[2].get_text()
  linking = infos[3].get_text()
  rank_df.loc[rank] = [rank, website, time, pageview, traffic, linking]

rank_df
# Out:
#    Rank                 Site  ... % of Traffic From Search Total Sites Linking In
# 1     1           Google.com  ...                    0.40%              1,363,003
# 2     2          Youtube.com  ...                   15.20%              1,041,468
# 3     3            Baidu.com  ...                    5.10%                105,530
# 4     4               Qq.com  ...                    3.00%                267,067
# 5     5             Sohu.com  ...                    1.60%                 28,192
# 6     6         Facebook.com  ...                    8.30%              2,393,525
# 7     7           Taobao.com  ...                    3.20%                 25,859
# 8     8               360.cn  ...                    0.40%                 15,829
# 9     9               Jd.com  ...                    1.40%                  8,913
# 10   10            Yahoo.com  ...                    7.80%                325,659
# 11   11           Amazon.com  ...                   19.80%                367,350
# 12   12        Wikipedia.org  ...                   73.30%                789,627
# 13   13          Sina.com.cn  ...                    2.60%                 49,797
# 14   14            Weibo.com  ...                    2.00%                 72,927
# 15   15           Reddit.com  ...                   28.50%                179,063
# 16   16             Live.com  ...                   10.60%                 31,506
# 17   17              Zoom.us  ...                   15.60%                  2,806
# 18   18          Netflix.com  ...                    9.40%                 10,694
# 19   19        Xinhuanet.com  ...                    2.70%                 36,317
# 20   20          Okezone.com  ...                    6.50%                 11,013
# 21   21        Microsoft.com  ...                   28.80%                243,021
# 22   22        Instagram.com  ...                   13.60%                685,115
# 23   23               Vk.com  ...                    9.00%                138,858
# 24   24           Office.com  ...                    8.20%                  5,786
# 25   25           Alipay.com  ...                    1.40%                  3,527
# 26   26        Myshopify.com  ...                    3.30%                    122
# 27   27             Csdn.net  ...                    7.00%                  6,716
# 28   28          Yahoo.co.jp  ...                   12.80%                 60,260
# 29   29        Bongacams.com  ...                    8.50%                134,779
# 30   30            Twitch.tv  ...                    6.50%                 10,116
# 31   31             Panda.tv  ...                    0.80%                    361
# 32   32            Zhanqi.tv  ...                    0.80%                    382
# 33   33        Google.com.hk  ...                    3.10%                  8,499
# 34   34             Bing.com  ...                    5.90%                 42,768
# 35   35            Naver.com  ...                   10.00%                 40,743
# 36   36       Aliexpress.com  ...                   13.70%                 20,100
# 37   37             Ebay.com  ...                   15.90%                 75,544
# 38   38         China.com.cn  ...                    1.10%                 13,565
# 39   39  Microsoftonline.com  ...                    3.00%                    713
# 40   40            Amazon.in  ...                   25.70%                  7,052
# 41   41            Tianya.cn  ...                    1.00%                  5,606
# 42   42    Stackoverflow.com  ...                   74.50%                 27,402
# 43   43          Twitter.com  ...                   11.60%              1,754,286
# 44   44       Tribunnews.com  ...                   61.50%                 21,711
# 45   45         Amazon.co.jp  ...                   16.20%                 51,354
# 46   46         Google.co.in  ...                   10.00%                 16,182
# 47   47       Chaturbate.com  ...                    9.80%                 78,022
#
# [47 rows x 6 columns]

# %%
from bs4 import  BeautifulSoup
import urllib.request
import pandas as pd

url = "https://www.alexa.com/topsites/countries/US"
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url, 'html.parser')
rank_df = pd.DataFrame(columns=("Rank", "Site", "Daily Time on Site", "Daily Pageviews per Visitor", "% of Traffic From Search", "Total Sites Linking In"))

sites = soup.find_all('div', {'class':'tr site-listing'})

for site in sites:
  rank = site.find('div', {'class': 'td'}).get_text()
  website = site.select('p > a')[0].get_text()
  infos = site.find_all('div', {'class': 'td right'})
  time = infos[0].get_text()
  pageview = infos[1].get_text()
  traffic = infos[2].get_text()
  linking = infos[3].get_text()
  rank_df.loc[rank] = [rank, website, time, pageview, traffic, linking]

rank_df
# Out:
#    Rank                 Site  ... % of Traffic From Search Total Sites Linking In
# 1     1           Google.com  ...                    0.40%              1,363,003
# 2     2          Youtube.com  ...                   15.20%              1,041,468
# 3     3           Amazon.com  ...                   19.80%                367,350
# 4     4            Yahoo.com  ...                    7.80%                325,659
# 5     5         Facebook.com  ...                    8.30%              2,393,525
# 6     6           Reddit.com  ...                   28.50%                179,063
# 7     7              Zoom.us  ...                   15.60%                  2,806
# 8     8        Wikipedia.org  ...                   73.30%                789,627
# 9     9        Myshopify.com  ...                    3.30%                    122
# 10   10             Ebay.com  ...                   15.90%                 75,544
# 11   11          Netflix.com  ...                    9.40%                 10,694
# 12   12             Bing.com  ...                    5.90%                 42,768
# 13   13           Office.com  ...                    8.20%                  5,786
# 14   14             Live.com  ...                   10.60%                 31,506
# 15   15            Twitch.tv  ...                    6.50%                 10,116
# 16   16        Microsoft.com  ...                   28.80%                243,021
# 17   17        Instagram.com  ...                   13.60%                685,115
# 18   18       Chaturbate.com  ...                    9.80%                 78,022
# 19   19  Microsoftonline.com  ...                    3.00%                    713
# 20   20            Chase.com  ...                    8.60%                  1,213
# 21   21           Zillow.com  ...                   31.50%                  9,104
# 22   22              Cnn.com  ...                   21.70%                112,979
# 23   23         Linkedin.com  ...                   13.80%                673,403
# 24   24            Apple.com  ...                   36.90%                179,799
# 25   25             Etsy.com  ...                   19.90%                100,619
# 26   26          Dropbox.com  ...                    7.60%                 22,710
# 27   27       Aliexpress.com  ...                   13.70%                 20,100
# 28   28          Walmart.com  ...                   28.80%                 17,803
# 29   29             Espn.com  ...                   12.50%                  9,356
# 30   30          Nytimes.com  ...                   28.40%                161,906
# 31   31            Adobe.com  ...                   25.10%                256,966
# 32   32       Craigslist.org  ...                   22.40%                 14,742
# 33   33          Twitter.com  ...                   11.60%              1,754,286
# 34   34      Instructure.com  ...                    6.30%                    992
# 35   35       Sharepoint.com  ...                    3.30%                     71
# 36   36       Wellsfargo.com  ...                   11.50%                  2,205
# 37   37             Okta.com  ...                    2.90%                    257
# 38   38       Livejasmin.com  ...                    3.70%                 12,475
# 39   39            Imgur.com  ...                    7.90%                257,081
# 40   40        Homedepot.com  ...                   44.20%                 11,891
# 41   41       Salesforce.com  ...                    5.90%                  4,639
# 42   42             Hulu.com  ...                    9.40%                 11,065
# 43   43          Pornhub.com  ...                   26.10%                  4,087
# 44   44    Stackoverflow.com  ...                   74.50%                 27,402
# 45   45             Imdb.com  ...                   47.40%                141,643
# 46   46              Msn.com  ...                    7.20%                 96,772
# 47   47               Ca.gov  ...                   31.70%                 40,109
# 48   48           Indeed.com  ...                   25.50%                  7,947
# 49   49             Usps.com  ...                   22.80%                  7,607
#
# [49 rows x 6 columns]

# %%
from bs4 import  BeautifulSoup
import urllib.request
import pandas as pd

url = "https://www.alexa.com/topsites/countries/KR"
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url, 'html.parser')
rank_df = pd.DataFrame(columns=("Rank", "Site", "Daily Time on Site", "Daily Pageviews per Visitor", "% of Traffic From Search", "Total Sites Linking In"))

sites = soup.find_all('div', {'class':'tr site-listing'})

for site in sites:
  rank = site.find('div', {'class': 'td'}).get_text()
  website = site.select('p > a')[0].get_text()
  infos = site.find_all('div', {'class': 'td right'})
  time = infos[0].get_text()
  pageview = infos[1].get_text()
  traffic = infos[2].get_text()
  linking = infos[3].get_text()
  rank_df.loc[rank] = [rank, website, time, pageview, traffic, linking]

rank_df
# Out:
#    Rank               Site  ... % of Traffic From Search Total Sites Linking In
# 1     1         Google.com  ...                    0.40%              1,363,003
# 2     2          Naver.com  ...                   10.00%                 40,743
# 3     3        Youtube.com  ...                   15.20%              1,041,468
# 4     4           Daum.net  ...                    4.90%                 15,413
# 5     5        Tistory.com  ...                   24.80%                  9,842
# 6     6          Kakao.com  ...                    8.30%                 11,487
# 7     7       Google.co.kr  ...                   10.60%                  4,851
# 8     8         Amazon.com  ...                   19.80%                367,350
# 9     9           Sohu.com  ...                    1.60%                 28,192
# 10   10       Facebook.com  ...                    8.30%              2,393,525
# 11   11             Qq.com  ...                    3.00%                267,067
# 12   12          Namu.wiki  ...                   21.60%                    112
# 13   13        Netflix.com  ...                    9.40%                 10,694
# 14   14      Wikipedia.org  ...                   73.30%                789,627
# 15   15         Taobao.com  ...                    3.20%                 25,859
# 16   16        Coupang.com  ...                   13.10%                    412
# 17   17             360.cn  ...                    0.40%                 15,829
# 18   18             Jd.com  ...                    1.40%                  8,913
# 19   19          Baidu.com  ...                    5.10%                105,530
# 20   20       Dcinside.com  ...                   19.00%                    756
# 21   21      Microsoft.com  ...                   28.80%                243,021
# 22   22           Nate.com  ...                    5.00%                  2,240
# 23   23          Twitch.tv  ...                    6.50%                 10,116
# 24   24          Yahoo.com  ...                    7.80%                325,659
# 25   25      Instagram.com  ...                   13.60%                685,115
# 26   26          Apple.com  ...                   36.90%                179,799
# 27   27      Gmarket.co.kr  ...                   16.30%                  2,274
# 28   28        Sina.com.cn  ...                    2.60%                 49,797
# 29   29          Weibo.com  ...                    2.00%                 72,927
# 30   30  Stackoverflow.com  ...                   74.50%                 27,402
# 31   31          Nexon.com  ...                   12.60%                    708
# 32   32         Office.com  ...                    8.20%                  5,786
# 33   33          Donga.com  ...                   18.00%                  4,300
# 34   34          Adobe.com  ...                   25.10%                256,966
# 35   35         11st.co.kr  ...                    3.40%                  1,193
# 36   36          Yna.co.kr  ...                   14.20%                    565
# 37   37           Bing.com  ...                    5.90%                 42,768
# 38   38         Chosun.com  ...                   23.90%                  7,273
# 39   39          Joins.com  ...                   23.50%                  5,311
# 40   40      Auction.co.kr  ...                   11.90%                  1,251
# 41   41           Ebay.com  ...                   15.90%                 75,544
# 42   42        Inven.co.kr  ...                   32.80%                  1,328
# 43   43       Amazon.co.uk  ...                   18.90%                 57,237
# 44   44      Afreecatv.com  ...                    5.90%                    508
# 45   45        Yahoo.co.jp  ...                   12.80%                 60,260
# 46   46        Dropbox.com  ...                    7.60%                 22,710
# 47   47        Ruliweb.com  ...                   16.00%                    499
# 48   48            Bbc.com  ...                   26.40%                 47,425
#
# [48 rows x 6 columns]
