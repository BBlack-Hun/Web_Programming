# %% [markdown]
# # 한국환경공단 대기오염정보

# %% [markdown]
# ## 한국환경공단_측정소정보
#
# * https://data.go.kr/tcs/dss/selectApiDataDetailView.do?publicDataPk=15000660

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
from xml.etree import ElementTree
import pandas as pd


skey = 'qxBDZQ26hmfT9knHXAzGd4agH8LLJMezqvucW61DbUIsRF%2BcvZ0mrf5OLoV1k2TEAQlA19uLAfanRTPuMXR2JQ%3D%3D'

url = 'http://openapi.airkorea.or.kr/openapi/services/rest/MsrstnInfoInqireSvc/getNearbyMsrstnList'
params = '?' + 'ServiceKey=' + skey + '&' + \
urlencode({ quote_plus('tmX') : '244148.546388', 
            quote_plus('tmY') : '412423.75772', 
            quote_plus('ver') : '1.0' })
print(url + params)

request = Request(url + params)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
print(response_body)

root = ElementTree.fromstring(response_body)
df = pd.DataFrame()
for item in root.iter('item'):
  item_dict ={}
  item_dict['stationName'] = item.find('stationName').text
  item_dict['addr'] = item.find('addr').text
  item_dict['tm'] = item.find('tm').text
  df = df.append(item_dict, ignore_index=True)

df
# Out:
# http://openapi.airkorea.or.kr/openapi/services/rest/MsrstnInfoInqireSvc/getNearbyMsrstnList?ServiceKey=qxBDZQ26hmfT9knHXAzGd4agH8LLJMezqvucW61DbUIsRF%2BcvZ0mrf5OLoV1k2TEAQlA19uLAfanRTPuMXR2JQ%3D%3D&tmX=244148.546388&tmY=412423.75772&ver=1.0
# b'<?xml version="1.0" encoding="UTF-8"?>\r\n\r\n\r\n\r\n\r\n<response>\r\n\t<header>\r\n\t\t<resultCode>00</resultCode>\r\n\t\t<resultMsg>NORMAL SERVICE.</resultMsg>\r\n\t</header>\r\n\t<body>\r\n\t\t<items>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t\t<stationName>\xeb\x8c\x80\xec\xa0\x95\xec\x9d\x8d</stationName>\r\n\t\t\t\t\t<addr>\xec\xa0\x9c\xec\xa3\xbc \xec\x84\x9c\xea\xb7\x80\xed\x8f\xac\xec\x8b\x9c \xeb\x8c\x80\xec\xa0\x95\xec\x9d\x8d \xeb\x8f\x99\xec\x9d\xbc\xed\x95\x98\xeb\xaa\xa8\xeb\xa1\x9c149\xeb\xb2\x88\xea\xb8\xb8 21-8\xeb\x8c\x80\xec\xa0\x95\xec\xb2\xad\xec\x86\x8c\xeb\x85\x84 \xec\x88\x98\xeb\xa0\xa8\xea\xb4\x80</addr>\r\n\t\t\t\t\t<tm>0.0</tm>\r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t\t<stationName>\xeb\xb6\x80\xec\x82\xb0\xeb\xb6\x81\xed\x95\xad</stationName>\r\n\t\t\t\t\t<addr>\xeb\xb6\x80\xec\x82\xb0 \xeb\x8f\x99\xea\xb5\xac \xec\xb6\xa9\xec\x9e\xa5\xeb\x8c\x80\xeb\xa1\x9c 314\xec\x9e\x90\xec\x84\xb1\xeb\x8c\x80\xeb\xb6\x80\xeb\x91\x90(\xea\xb4\x80\xea\xb3\xb5\xec\x84\xa0\xeb\xb6\x80\xeb\x91\x90) \xeb\x82\xb4 (\xec\xa2\x8c\xec\xb2\x9c\xeb\x8f\x99)</addr>\r\n\t\t\t\t\t<tm>0.0</tm>\r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t\t<stationName>\xea\xb3\xa0\xec\x82\xb0\xeb\xa6\xac</stationName>\r\n\t\t\t\t\t<addr>\xec\xa0\x9c\xec\xa3\xbc \xec\xa0\x9c\xec\xa3\xbc\xec\x8b\x9c \xed\x95\x9c\xea\xb2\xbd\xeb\xa9\xb4 \xea\xb3\xa0\xec\x82\xb0\xeb\xa6\xac3762</addr>\r\n\t\t\t\t\t<tm>0.0</tm>\r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t</items>\r\n\t\t\t<numOfRows>10</numOfRows>\r\n\t\t\t<pageNo>1</pageNo>\r\n\t\t\t<totalCount>3</totalCount>\r\n\t</body>\r\n</response>\r\n'
#                                    addr stationName   tm
# 0  제주 서귀포시 대정읍 동일하모로149번길 21-8대정청소년 수련관         대정읍  0.0
# 1    부산 동구 충장대로 314자성대부두(관공선부두) 내 (좌천동)        부산북항  0.0
# 2                    제주 제주시 한경면 고산리3762         고산리  0.0

# %% [markdown]
# ## 한국환경공단_대기오염정보
#
# * https://data.go.kr/tcs/dss/selectApiDataDetailView.do?publicDataPk=15000581

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus

skey = 'qxBDZQ26hmfT9knHXAzGd4agH8LLJMezqvucW61DbUIsRF%2BcvZ0mrf5OLoV1k2TEAQlA19uLAfanRTPuMXR2JQ%3D%3D'

url = 'http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty'
params = '?' + 'ServiceKey=' + skey + '&' + \
urlencode({ quote_plus('numOfRows') : '10', 
            quote_plus('pageNo') : '1', 
            quote_plus('stationName') : '종로구',
            quote_plus('dataTerm') : 'DAILY', 
            quote_plus('ver') : '1.3' })
print(url + params)

request = Request(url + params)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
print(response_body)
# Out:
# http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty?ServiceKey=qxBDZQ26hmfT9knHXAzGd4agH8LLJMezqvucW61DbUIsRF%2BcvZ0mrf5OLoV1k2TEAQlA19uLAfanRTPuMXR2JQ%3D%3D&numOfRows=10&pageNo=1&stationName=%EC%A2%85%EB%A1%9C%EA%B5%AC&dataTerm=DAILY&ver=1.3
# b'<?xml version="1.0" encoding="UTF-8"?>\r\n\r\n\r\n\r\n\r\n<response>\r\n\t<header>\r\n\t\t<resultCode>00</resultCode>\r\n\t\t<resultMsg>NORMAL SERVICE.</resultMsg>\r\n\t</header>\r\n\t<body>\r\n\t\t<items>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t\t<dataTime>2020-08-25 24:00</dataTime>\r\n\t\t\t\t\t\r\n                        <mangName>\xeb\x8f\x84\xec\x8b\x9c\xeb\x8c\x80\xea\xb8\xb0</mangName>\r\n                    \r\n\t\t\t\t\t<so2Value>0.003</so2Value>\r\n\t\t\t\t\t<coValue>0.3</coValue>\r\n\t\t\t\t\t<o3Value>0.013</o3Value>\r\n\t\t\t\t\t<no2Value>0.019</no2Value>\r\n\t\t\t\t\t<pm10Value>26</pm10Value>\r\n\t\t\t\t\t\r\n                        <pm10Value24>28</pm10Value24>\r\n                    \r\n\t\t\t\t\t\r\n                        <pm25Value>21</pm25Value>\r\n                    \r\n                    \r\n                        <pm25Value24>22</pm25Value24>\r\n                    \r\n\t\t\t\t\t<khaiValue>66</khaiValue>\r\n\t\t\t\t\t<khaiGrade>2</khaiGrade>\r\n\t\t\t\t\t<so2Grade>1</so2Grade>\r\n\t\t\t\t\t<coGrade>1</coGrade>\r\n\t\t\t\t\t<o3Grade>1</o3Grade>\r\n\t\t\t\t\t<no2Grade>1</no2Grade>\r\n\t\t\t\t\t<pm10Grade>1</pm10Grade>\r\n\t\t\t\t\t\r\n                        <pm25Grade>2</pm25Grade>\r\n                    \r\n                    \r\n                        <pm10Grade1h>1</pm10Grade1h>\r\n                        <pm25Grade1h>2</pm25Grade1h>\r\n                    \r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t\t<dataTime>2020-08-25 23:00</dataTime>\r\n\t\t\t\t\t\r\n                        <mangName>\xeb\x8f\x84\xec\x8b\x9c\xeb\x8c\x80\xea\xb8\xb0</mangName>\r\n                    \r\n\t\t\t\t\t<so2Value>0.004</so2Value>\r\n\t\t\t\t\t<coValue>0.3</coValue>\r\n\t\t\t\t\t<o3Value>0.013</o3Value>\r\n\t\t\t\t\t<no2Value>0.019</no2Value>\r\n\t\t\t\t\t<pm10Value>26</pm10Value>\r\n\t\t\t\t\t\r\n                        <pm10Value24>29</pm10Value24>\r\n                    \r\n\t\t\t\t\t\r\n                        <pm25Value>20</pm25Value>\r\n                    \r\n                    \r\n                        <pm25Value24>22</pm25Value24>\r\n                    \r\n\t\t\t\t\t<khaiValue>66</khaiValue>\r\n\t\t\t\t\t<khaiGrade>2</khaiGrade>\r\n\t\t\t\t\t<so2Grade>1</so2Grade>\r\n\t\t\t\t\t<coGrade>1</coGrade>\r\n\t\t\t\t\t<o3Grade>1</o3Grade>\r\n\t\t\t\t\t<no2Grade>1</no2Grade>\r\n\t\t\t\t\t<pm10Grade>1</pm10Grade>\r\n\t\t\t\t\t\r\n                        <pm25Grade>2</pm25Grade>\r\n                    \r\n                    \r\n                        <pm10Grade1h>1</pm10Grade1h>\r\n                        <pm25Grade1h>2</pm25Grade1h>\r\n                    \r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t\t<dataTime>2020-08-25 22:00</dataTime>\r\n\t\t\t\t\t\r\n                        <mangName>\xeb\x8f\x84\xec\x8b\x9c\xeb\x8c\x80\xea\xb8\xb0</mangName>\r\n                    \r\n\t\t\t\t\t<so2Value>0.004</so2Value>\r\n\t\t\t\t\t<coValue>0.3</coValue>\r\n\t\t\t\t\t<o3Value>0.019</o3Value>\r\n\t\t\t\t\t<no2Value>0.014</no2Value>\r\n\t\t\t\t\t<pm10Value>27</pm10Value>\r\n\t\t\t\t\t\r\n                        <pm10Value24>30</pm10Value24>\r\n                    \r\n\t\t\t\t\t\r\n                        <pm25Value>22</pm25Value>\r\n                    \r\n                    \r\n                        <pm25Value24>23</pm25Value24>\r\n                    \r\n\t\t\t\t\t<khaiValue>69</khaiValue>\r\n\t\t\t\t\t<khaiGrade>2</khaiGrade>\r\n\t\t\t\t\t<so2Grade>1</so2Grade>\r\n\t\t\t\t\t<coGrade>1</coGrade>\r\n\t\t\t\t\t<o3Grade>1</o3Grade>\r\n\t\t\t\t\t<no2Grade>1</no2Grade>\r\n\t\t\t\t\t<pm10Grade>1</pm10Grade>\r\n\t\t\t\t\t\r\n                        <pm25Grade>2</pm25Grade>\r\n                    \r\n                    \r\n                        <pm10Grade1h>1</pm10Grade1h>\r\n                        <pm25Grade1h>2</pm25Grade1h>\r\n                    \r\n\t\t\t\t</item>\r\n\t\t\t\r\n\t\t\t\t<item>\r\n\t\t\t\t\t<dataTime>2020-08-25 21:00</dataTime>\r\n\t\t\t\t\t\r\n                        <mangN ...

# %% [markdown]
# ### 측정소별 실시간 측정정보 조회

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
from xml.etree import ElementTree
import pandas as pd


skey = 'qxBDZQ26hmfT9knHXAzGd4agH8LLJMezqvucW61DbUIsRF%2BcvZ0mrf5OLoV1k2TEAQlA19uLAfanRTPuMXR2JQ%3D%3D'

url = 'http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty'

params = '?' + 'ServiceKey=' + skey + '&' + \
urlencode({ quote_plus('numOfRows') : '10', quote_plus('pageNo') : '1', 
            quote_plus('stationName') : '종로구', quote_plus('dataTerm') : 'DAILY', 
            quote_plus('ver') : '1.3' })
print(url + params)

request = Request(url + params)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
#print(response_body)

root = ElementTree.fromstring(response_body)
df = pd.DataFrame()
for item in root.iter('item'):
  item_dict ={}
  item_dict['dataTime'] = item.find('dataTime').text
  item_dict['mangName'] = item.find('mangName').text
  item_dict['so2Value'] = item.find('so2Value').text
  item_dict['coValue'] = item.find('coValue').text
  item_dict['o3Value'] = item.find('o3Value').text
  item_dict['no2Value'] = item.find('no2Value').text
  item_dict['pm10Value'] = item.find('pm10Value').text
  item_dict['pm10Value24'] = item.find('pm10Value24').text
  item_dict['pm25Value'] = item.find('pm25Value').text
  item_dict['pm25Value24'] = item.find('pm25Value24').text
  item_dict['khaiValue'] = item.find('khaiValue').text
  item_dict['khaiGrade'] = item.find('khaiGrade').text
  item_dict['so2Grade'] = item.find('so2Grade').text
  item_dict['coGrade'] = item.find('coGrade').text
  item_dict['o3Grade'] = item.find('o3Grade').text
  item_dict['no2Grade'] = item.find('no2Grade').text
  item_dict['pm10Grade'] = item.find('pm10Grade').text
  item_dict['pm25Grade'] = item.find('pm25Grade').text
  item_dict['pm10Grade1h'] = item.find('pm10Grade1h').text
  item_dict['pm25Grade1h'] = item.find('pm25Grade1h').text

  
  df = df.append(item_dict, ignore_index=True)

df
# Out:
# http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getMsrstnAcctoRltmMesureDnsty?ServiceKey=qxBDZQ26hmfT9knHXAzGd4agH8LLJMezqvucW61DbUIsRF%2BcvZ0mrf5OLoV1k2TEAQlA19uLAfanRTPuMXR2JQ%3D%3D&numOfRows=10&pageNo=1&stationName=%EC%A2%85%EB%A1%9C%EA%B5%AC&dataTerm=DAILY&ver=1.3
#   coGrade coValue          dataTime  ... pm25Value24 so2Grade so2Value
# 0       1     0.3  2020-08-25 24:00  ...          22        1    0.003
# 1       1     0.3  2020-08-25 23:00  ...          22        1    0.004
# 2       1     0.3  2020-08-25 22:00  ...          23        1    0.004
# 3       1     0.3  2020-08-25 21:00  ...          24        1    0.004
# 4       1     0.3  2020-08-25 20:00  ...          24        1    0.004
# 5       1     0.3  2020-08-25 19:00  ...          24        1    0.004
# 6       1     0.4  2020-08-25 18:00  ...          23        1    0.005
# 7       1     0.4  2020-08-25 17:00  ...          22        1    0.005
# 8       1     0.3  2020-08-25 16:00  ...          21        1    0.005
# 9       1     0.3  2020-08-25 15:00  ...          21        1    0.004
#
# [10 rows x 20 columns]

# %% [markdown]
# ### 시도별 실시간 측정정보 조회

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
from xml.etree import ElementTree
import pandas as pd


skey = 'qxBDZQ26hmfT9knHXAzGd4agH8LLJMezqvucW61DbUIsRF%2BcvZ0mrf5OLoV1k2TEAQlA19uLAfanRTPuMXR2JQ%3D%3D'

url = 'http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty'

params = '?' + 'ServiceKey=' + skey + '&' + \
urlencode({ quote_plus('numOfRows') : '10', quote_plus('pageNo') : '1', 
            quote_plus('sidoName') : '인천',
            quote_plus('ver') : '1.3' })
print(url + params)

request = Request(url + params)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
#print(response_body)

root = ElementTree.fromstring(response_body)
df = pd.DataFrame()
for item in root.iter('item'):
  item_dict ={}
  item_dict['stationName'] = item.find('stationName').text
  item_dict['mangName'] = item.find('mangName').text
  item_dict['dataTime'] = item.find('dataTime').text
  item_dict['so2Value'] = item.find('so2Value').text
  item_dict['coValue'] = item.find('coValue').text
  item_dict['o3Value'] = item.find('o3Value').text
  item_dict['no2Value'] = item.find('no2Value').text
  item_dict['pm10Value'] = item.find('pm10Value').text
  item_dict['pm10Value24'] = item.find('pm10Value24').text
  item_dict['pm25Value'] = item.find('pm25Value').text
  item_dict['pm25Value24'] = item.find('pm25Value24').text
  item_dict['khaiValue'] = item.find('khaiValue').text
  item_dict['khaiGrade'] = item.find('khaiGrade').text
  item_dict['so2Grade'] = item.find('so2Grade').text
  item_dict['coGrade'] = item.find('khaiGrade').text
  item_dict['o3Grade'] = item.find('khaiGrade').text
  item_dict['no2Grade'] = item.find('khaiGrade').text
  item_dict['pm10Grade'] = item.find('khaiGrade').text
  item_dict['pm25Grade'] = item.find('khaiGrade').text
  item_dict['pm10Grade1h'] = item.find('khaiGrade').text
  item_dict['pm25Grade1h'] = item.find('khaiGrade').text

  
  df = df.append(item_dict, ignore_index=True)

df
# Out:
# http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getCtprvnRltmMesureDnsty?ServiceKey=qxBDZQ26hmfT9knHXAzGd4agH8LLJMezqvucW61DbUIsRF%2BcvZ0mrf5OLoV1k2TEAQlA19uLAfanRTPuMXR2JQ%3D%3D&numOfRows=10&pageNo=1&sidoName=%EC%9D%B8%EC%B2%9C&ver=1.3
#   coGrade coValue          dataTime  ... so2Grade so2Value stationName
# 0       2     0.3  2020-08-25 24:00  ...        1    0.004          신흥
# 1       2     0.5  2020-08-25 24:00  ...        1    0.002          서해
# 2       2     0.5  2020-08-25 24:00  ...        1    0.002          송림
# 3       1     0.3  2020-08-25 24:00  ...        1    0.003         구월동
# 4       2     0.3  2020-08-25 24:00  ...        1    0.004          숭의
# 5       2     0.4  2020-08-25 24:00  ...        1    0.003         석바위
# 6    None     0.4  2020-08-25 24:00  ...        1    0.005         부평역
# 7       1     0.7  2020-08-25 24:00  ...        1    0.002          남동
# 8       2     0.3  2020-08-25 24:00  ...        1    0.004          부평
# 9    None     0.3  2020-08-25 24:00  ...        1    0.004          연희
#
# [10 rows x 21 columns]

# %% [markdown]
# ### 시도별 실시간 평균정보 조회

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
from xml.etree import ElementTree
import pandas as pd


skey = 'qxBDZQ26hmfT9knHXAzGd4agH8LLJMezqvucW61DbUIsRF%2BcvZ0mrf5OLoV1k2TEAQlA19uLAfanRTPuMXR2JQ%3D%3D'

url = 'http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getCtprvnMesureLIst'

params = '?' + 'ServiceKey=' + skey + '&' + \
urlencode({ quote_plus('numOfRows') : '10', quote_plus('pageNo') : '1', 
            quote_plus('itemCode') : 'PM10', quote_plus('dataGubun') : 'HOUR',
            quote_plus('searchCondition') : 'MONTH' })
print(url + params)

request = Request(url + params)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
#print(response_body)

root = ElementTree.fromstring(response_body)
df = pd.DataFrame()
for item in root.iter('item'):
  item_dict ={}
  item_dict['dataTime'] = item.find('dataTime').text
  item_dict['itemCode'] = item.find('itemCode').text
  item_dict['dataGubun'] = item.find('dataGubun').text
  item_dict['seoul'] = item.find('seoul').text
  item_dict['busan'] = item.find('busan').text
  item_dict['daegu'] = item.find('daegu').text
  item_dict['incheon'] = item.find('incheon').text
  item_dict['gwangju'] = item.find('gwangju').text
  item_dict['daejeon'] = item.find('daejeon').text
  item_dict['ulsan'] = item.find('ulsan').text
  item_dict['gyeonggi'] = item.find('gyeonggi').text
  item_dict['gangwon'] = item.find('gangwon').text
  item_dict['chungbuk'] = item.find('chungbuk').text
  item_dict['chungnam'] = item.find('chungnam').text
  item_dict['jeonbuk'] = item.find('jeonbuk').text
  item_dict['jeonnam'] = item.find('jeonnam').text
  item_dict['gyeongbuk'] = item.find('gyeongbuk').text
  item_dict['gyeongnam'] = item.find('gyeongnam').text
  item_dict['jeju'] = item.find('jeju').text
  item_dict['sejong'] = item.find('sejong').text
  

  
  df = df.append(item_dict, ignore_index=True)

df
# Out:
# http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getCtprvnMesureLIst?ServiceKey=qxBDZQ26hmfT9knHXAzGd4agH8LLJMezqvucW61DbUIsRF%2BcvZ0mrf5OLoV1k2TEAQlA19uLAfanRTPuMXR2JQ%3D%3D&numOfRows=10&pageNo=1&itemCode=PM10&dataGubun=HOUR&searchCondition=MONTH
#   busan chungbuk chungnam daegu daejeon  ... jeonbuk jeonnam sejong seoul ulsan
# 0    35       23       33    46      18  ...      23      34     20    28    45
# 1    38       22       33    48      18  ...      25      34     21    28    50
# 2    42       24       33    43      20  ...      26      32     24    27    53
# 3    42       25       32    34      22  ...      25      29     28    28    54
# 4    45       24       34    31      22  ...      21      28     33    31    53
# 5    52       23       30    26      21  ...      22      27     25    34    60
# 6    58       21       30    28      17  ...      22      27     21    33    63
# 7    62       19       27    29      19  ...      24      29     24    33    63
# 8    60       18       25    31      20  ...      25      30     17    28    68
# 9    61       18       24    29    None  ...      25      32     18    27    61
#
# [10 rows x 20 columns]

# %% [markdown]
# ### 시군구별 실시간 평균정보 조회

# %%
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus
from xml.etree import ElementTree
import pandas as pd


skey = 'qxBDZQ26hmfT9knHXAzGd4agH8LLJMezqvucW61DbUIsRF%2BcvZ0mrf5OLoV1k2TEAQlA19uLAfanRTPuMXR2JQ%3D%3D'

url = 'http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getCtprvnMesureSidoLIst'

params = '?' + 'ServiceKey=' + skey + '&' + \
urlencode({ quote_plus('numOfRows') : '10', quote_plus('pageNo') : '1', 
            quote_plus('sidoName') : '서울', quote_plus('searchCondition') : 'DAILY'})
print(url + params)

request = Request(url + params)
request.get_method = lambda: 'GET'
response_body = urlopen(request).read()
#print(response_body)

root = ElementTree.fromstring(response_body)
df = pd.DataFrame()
for item in root.iter('item'):
  item_dict ={}
  item_dict['dataTime'] = item.find('dataTime').text
  item_dict['cityName'] = item.find('cityName').text
  item_dict['so2Value'] = item.find('so2Value').text
  item_dict['coValue'] = item.find('coValue').text
  item_dict['o3Value'] = item.find('o3Value').text
  item_dict['no2Value'] = item.find('no2Value').text
  item_dict['pm10Value'] = item.find('pm10Value').text
  item_dict['pm25Value'] = item.find('pm25Value').text
  
  

  
  df = df.append(item_dict, ignore_index=True)

df
# Out:
# http://openapi.airkorea.or.kr/openapi/services/rest/ArpltnInforInqireSvc/getCtprvnMesureSidoLIst?ServiceKey=qxBDZQ26hmfT9knHXAzGd4agH8LLJMezqvucW61DbUIsRF%2BcvZ0mrf5OLoV1k2TEAQlA19uLAfanRTPuMXR2JQ%3D%3D&numOfRows=10&pageNo=1&sidoName=%EC%84%9C%EC%9A%B8&searchCondition=DAILY
#   cityName coValue          dataTime  ... pm10Value pm25Value so2Value
# 0      강남구     0.3  2020-08-25 24:00  ...        27        24    0.003
# 1      강동구     0.3  2020-08-25 24:00  ...         -        29        -
# 2      강북구     0.2  2020-08-25 24:00  ...        37        25    0.003
# 3      강서구     0.3  2020-08-25 24:00  ...        30        27    0.006
# 4      관악구     0.4  2020-08-25 24:00  ...        29        20    0.003
# 5      광진구     0.3  2020-08-25 24:00  ...        28        19    0.004
# 6      구로구     0.3  2020-08-25 24:00  ...        25        12    0.003
# 7      금천구     0.3  2020-08-25 24:00  ...        28        21    0.003
# 8      노원구     0.3  2020-08-25 24:00  ...        28        23    0.003
# 9      도봉구     0.1  2020-08-25 24:00  ...         -        17    0.003
#
# [10 rows x 8 columns]
