# %% [markdown]
# # 네이버 검색 API 서비스

# %% [markdown]
# ## 네이버 서비스 API 신청
#
# 1. 네이버 개발자센터: https://developers.naver.com/products/search/
# 2. 어플리케이션 등록
# 3. 클라이언트 ID/SECRET 확인

# %% [markdown]
# ## NAVER 서비스 API 종류
# | 항목 | 주소                                         |
# |------|----------------------------------------------|
# |블로그| https://openapi.naver.com/v1/search/blog.json |
# |뉴스　| https://openapi.naver.com/v1/search/news.json |
# | 책　 | https://openapi.naver.com/v1/search/book.json|
# | 성인 검색어 판별|　https://openapi.naver.com/v1/search/adult.json|
# | 백과사전| https://openapi.naver.com/v1/search/encyc.json|
# | 영화| https://openapi.naver.com/v1/search/movie.json|
# | 카페글 |https://openapi.naver.com/v1/search/cafearticle.json|
# | 지식in| https://openapi.naver.com/v1/search/kin.json|
# | 지역 | https://openapi.naver.com/v1/search/local.json|
# | 오타변환 | https://openapi.naver.com/v1/search/errata.json|
# | 웹문서 | https://openapi.naver.com/v1/search/webkr.json|
# | 이미지 | https://openapi.naver.com/v1/search/image.json|
# | 쇼핑 | https://openapi.naver.com/v1/search/shop.json|
# | 전문자료 | https://openapi.naver.com/v1/search/doc.json|

# %% [markdown]
# ## 네이버 웹문서 검색 API

# %%
import os
import sys
import urllib.request
client_id = "WowZ7jVFhwfw9UZwT1jr"
client_secret = "nKIhVXKvZY"

encText = urllib.parse.quote("컴퓨터")

url = "https://openapi.naver.com/v1/search/webkr?query=" + encText # json 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Tue, 25 Aug 2020 21:45:49 +0900",
# "total": 23848302,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>컴퓨터</b> - 나무위키",
# "link": "https://namu.wiki/w/%EC%BB%B4%ED%93%A8%ED%84%B0%20",
# "description": "<b>컴퓨터</b>에 대한 내용은 PC 문서를 참조하십시오. 관련 문서: 전자기기 관련 정보, 공학 관련 정보, 수학 관련 정보 하위 문서: <b>컴퓨터</b> 관련... 1981 → <b>컴퓨터</b> 1982 → 로널드 레이건 , 유리 안드로포프 1983 1. 개요 1.... "
#
# },
# {
# "title": "슈퍼<b>컴퓨터</b> - 나무위키",
# "link": "https://namu.wiki/w/%EC%8A%88%ED%8D%BC%EC%BB%B4%ED%93%A8%ED%84%B0",
# "description": "가장 빠른 슈퍼<b>컴퓨터</b> 연혁 4.2. 대한민국의 슈퍼<b>컴퓨터</b> 도입 4.2.1. 기상청 4.2.2. KISTI 4.2.3. NFRI... 가상의 슈퍼<b>컴퓨터</b> 1. 개요 [편집] 일반적인 <b>컴퓨터</b>에 비해 월등한 연산 능력을 보유한 <b>컴퓨터</b>를 말한다. 어느... "
#
# },
# {
# "title": "주연테크",
# "link": "https://www.jooyon.co.kr/",
# "description": "주연테크 회사소개 및 <b>컴퓨터</b>,PC,데스크탑,모니터,노트북,태블릿,TV,CCTV 등 제품소개/고객서비스 안내"
#
# },
# {
# "title": "TG삼보",
# "link": "https://www.trigem.co.kr/",
# "description": "<b>컴퓨터</b>, 모니터, 노트북 제조판매 등 제품소개, AS 안내."
#
# },
# {
# "title": "한글과<b>컴퓨터</b>",
# "link": "https://www.hancom.com/",
# "description": "한컴오피스, 씽크프리, 전자책, 앱북, 솔루션 제품 체험판, 뷰어 다운로드 및 고객지원 등 안내."
#
# },
# {
# "title": "호서대학교 <b>컴퓨터</b>정보공학부",
# "link": "http://www.hoseo.ac.kr/Home/Major.mbz?action=MAPP_1905081184",
# "description": "<b>컴퓨터</b>정보공학부 Division of Computer and Information Engineering <b>컴퓨터</b>정보분야는 고도화된 정보화... 이러한 기술적 수요 요구에 부응하기 위해, 호서대학교 <b>컴퓨터</b>공학부는 3개의 트랙, 즉... "
#
# },
# {
# "title": "(주)늑대와여우<b>컴퓨터</b>",
# "link": "http://www.nycomputer.co.kr/",
# "description": "<b>컴퓨터</b> 및 주변기기, 소형가전 쇼핑몰, 모니터, 데스크탑, mp3, 디지털카메라 등 판매."
#
# },
# {
# "title": "바이오 <b>컴퓨터</b> - 나무위키",
# "link": "https://namu.wiki/w/%EB%B0%94%EC%9D%B4%EC%98%A4%20%EC%BB%B4%ED%93%A8%ED%84%B0",
# "description": "소니의 노트북 <b>컴퓨터</b> 모델에 대해서는 VAIO 항목을 참조할 것. 1. <b>컴퓨터</b> 기술의 일종 1.1. 생체 부품을 사용하는 <b>컴퓨터</b> 1.1.1. 바이오칩, 바이오 소자 1.1.2. 통 속의 뇌 1.2. 인공신경망과 뉴로모픽 <b>컴퓨터</b> 2.... "
#
# },
# {
# "title": "IBM",
# "link": "https://www.ibm.com/",
# "description": "For more than a century IBM has been dedicated to every client's success and to creating innovations that matter for the world"
#
# },
# {
# "title": "한컴오피스 한글 2014 VP for Mac 가정 및 학생용 다운로드형",
# "link": "https://www.hancom.com/goods/goodsView.do?goods_seq=1584",
# "description": "판매가 59,900원 상품코드 C001584 제조사 / 공급사 한글과<b>컴퓨터</b>/ 한글과<b>컴퓨터</b> 구매수량 사용가능쿠폰... 배송비 한글과<b>컴퓨터</b> 전상품은 무료배송이며, 입점상품의 경우 배송비가 발생할 수 있습니다. (단... "
#
# }
# ]
# }

# %% [markdown]
# ## 네이버 지식iN 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re
client_id = "WowZ7jVFhwfw9UZwT1jr"
client_secret = "nKIhVXKvZY"

query = urllib.parse.quote(input("검색질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

kin_df = pd.DataFrame(columns=("Title", "Link", "Description"))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/kin?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        kin_df.loc[idx] = [title, link, description]
        idx +=1
  else:
      print("Error Code:" + rescode)

kin_df
# Out:
# 검색질의: 컴퓨터
#                 Title  ...                                        Description
# 0        학점은행제 컴퓨터공학이  ...  ... 컴퓨터공학을 따려고 하는 직장인인데 대학교보다 학점은행제 컴퓨터공학이 더 빠...
# 1     컴퓨터공학 편입 하는 방법?  ...  저는 고졸이고요 컴퓨터공학 편입을 하려고 하는데요 컴퓨터공학 편입 진학조건을 잘 모...
# 2        학점은행제 컴퓨터공학!  ...  학점은행제 컴퓨터공학 학사학위 취득을 희망합니다. 학점은행제 컴퓨터공학 학사학위를 ...
# 3         학점은행제 컴퓨터공학  ...  ... 하던데 컴퓨터공학 있나요? 학점은행제 컴퓨터공학은 전공이 있나요 없나요? 학...
# 4             조립식컴퓨터랑  ...  조립식컴퓨터랑 그냥 컴퓨터랑 성능 면에서 차이가 있나요? 질문자님을 뵙게 되어 감사...
# ..                ...  ...                                                ...
# 995     컴퓨터 사양 좀 봐주세요  ...  이번에 컴퓨터를 살려고 하는데 제가 쓰는건 아니고 저희 부모님이 쓰실 컴퓨터입니다....
# 996           컴퓨터와 건강  ...  ... 제가 여쭙고 싶은 것은 '컴퓨터와 건강'에 관한 것입니다. 학교에서 컴퓨터 ...
# 997  컴퓨터자격증 취업도움되나요??  ...  ... 위해 컴퓨터자격증을 몇개 취득해놓고싶은데요 실무에서는 컴퓨터자격증이 있으면 ...
# 998     컴퓨터보안전문가가 되려면  ...  ... 근데 그냥저냥 한동안 잊고 살았는데, 얼마전에 컴퓨터보안전문가 에 대해 알게...
# 999         컴퓨터공학과 순위  ...  문득 컴퓨터공학과 순위에 대해 궁금해졌습니다. 전문대 컴퓨터공학과이구요.. 성적 나...
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## 네이버 뉴스 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re
client_id = "WowZ7jVFhwfw9UZwT1jr"
client_secret = "nKIhVXKvZY"

query = urllib.parse.quote(input("검색질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

news_df = pd.DataFrame(columns=("Title", "Original Link", "Link", "Description", "Publication Date"))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/news?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        original_link = items[item_index]['originallink']
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        pub_date = items[item_index]['pubDate']
        news_df.loc[idx] = [title, original_link, link, description, pub_date]
        idx +=1
  else:
      print("Error Code:" + rescode)

news_df
# Out:
# 검색질의: 컴퓨터
#                                    Title  ...                 Publication Date
# 0         비트컴퓨터, 의원급 클라우드 의료서비스 비트플러스 출시  ...  Tue, 25 Aug 2020 18:18:00 +0900
# 1             핵융합 상용화 난제 해결할 슈퍼컴퓨터 구축 완료  ...  Mon, 24 Aug 2020 23:37:00 +0900
# 2           비트컴퓨터, 의원급 의료기관용 클라우드 플랫폼 출시  ...  Tue, 25 Aug 2020 10:42:00 +0900
# 3             핵융합 상용화 난제 해결할 슈퍼컴퓨터 구축 완료  ...  Mon, 24 Aug 2020 09:17:00 +0900
# 4    비트컴퓨터, 1차 의료기관용 클라우드 플랫폼 '비트플러스' 출시  ...  Tue, 25 Aug 2020 09:40:00 +0900
# ..                                   ...  ...                              ...
# 995           와이즈유, 2021학년도 AI·컴퓨터공학과 신설  ...  Wed, 20 May 2020 16:44:00 +0900
# 996         보안 철저한 신천지 컴퓨터, 외부에선 파일 못 열어  ...  Sun, 15 Mar 2020 11:47:00 +0900
# 997     '온라인 개학' 한국수자원공사 대전시에 학습용 컴퓨터 기증  ...  Mon, 13 Apr 2020 17:20:00 +0900
# 998     신한생명, 소외아동에 코로나19 온라인 강의용 컴퓨터 지원  ...  Mon, 13 Apr 2020 09:28:00 +0900
# 999           KISTI, 코로나19 슈퍼컴퓨터 컨소시엄 가입  ...  Fri, 17 Jul 2020 13:30:00 +0900
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## 네이버 블로그 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re
client_id = "WowZ7jVFhwfw9UZwT1jr"
client_secret = "nKIhVXKvZY"

query = urllib.parse.quote(input("검색질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

blog_df = pd.DataFrame(columns=("Title", "Link", "Description", "Blogger Name", "Blogger Link", "Post Date"))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/blog?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        blogger_name = items[item_index]["bloggername"]
        blogger_link = items[item_index]["bloggerlink"]
        post_date = items[item_index]['postdate']
        blog_df.loc[idx] = [title, link, description, blogger_name, blogger_link, post_date]
        idx +=1
  else:
      print("Error Code:" + rescode)

blog_df
# Out:
# 검색질의: 컴퓨터
#                                    Title  ... Post Date
# 0                        용산 조립컴퓨터 만족스러워요  ...  20200824
# 1                   국비지원컴퓨터학원 현명한 선택이 필수  ...  20200720
# 2                     강남컴퓨터학원 꿈을 위한 한걸음!  ...  20200825
# 3                       컴퓨터학원 취업까지 현명하게!  ...  20200825
# 4                      컴퓨터학원 눈 여겨 봐야할 점!  ...  20200819
# ..                                   ...  ...       ...
# 995  컴퓨터의자, 사무실의자로도 편한 에이픽스프라임 GC004...   ...  20200408
# 996               가성비 좋은 콜오브듀티 워존 컴퓨터 사양  ...  20200404
# 997              라이젠 3600 마티스 기반 게이밍 컴퓨터  ...  20190713
# 998                 RTX2080Ti 최고사양 조립컴퓨터  ...  20200103
# 999                     컴퓨터 소음 원인과 없애는 법  ...  20200308
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## 네이버 책 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re
client_id = "WowZ7jVFhwfw9UZwT1jr"
client_secret = "nKIhVXKvZY"

query = urllib.parse.quote(input("검색질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

book_df = pd.DataFrame(columns=("Title", "Link", "Image", "Authre Name", "Price", "Discount", "Publisher", "ISBN", "Description", "Publication Date" ))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/book?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        image = items[item_index]['image']
        author = items[item_index]['author']
        price = items[item_index]['price']
        discount = items[item_index]['discount']
        publisher = items[item_index]['publisher']
        isbn = items[item_index]['isbn']
        description = re.sub(remove_tag, '', items[item_index]['description'])
        pub_date = items[item_index]['pubdate']
        book_df.loc[idx] = [title, link, image, author, price, discount, publisher, isbn, description, pub_date]
        idx +=1
  else:
      print("Error Code:" + rescode)

book_df
# Out:
# 검색질의: 컴퓨터
#                                                  Title  ... Publication Date
# 0    시나공 총정리 컴퓨터활용능력 1급 필기 (핵심요약+기출문제+모의고사+암기프로그램+기...  ...         20190909
# 1                              시나공 컴퓨터활용능력 2급실기 (2020)  ...         20191008
# 2                              시나공 컴퓨터활용능력1급 실기 (2020)  ...         20191010
# 3    시나공 총정리 컴퓨터활용능력 2급 필기 (핵심요약+기출문제+모의고사+암기프로그램+기...  ...         20190909
# 4    시나공 컴퓨터활용능력 1급 필기 (필수암기집+동영상강의+암기프로그램+기출CBT,2020)  ...         20191028
# ..                                                 ...  ...              ...
# 995  컴퓨터 일반 쪽집게 기출문제집 + 정답 및 해설 세트 (2017,전산직 계리직 군무...  ...         20170104
# 996              이기적 in 컴퓨터그래픽스 운용기능사 필기 기본서 세트 (2016)  ...         20151030
# 997                                            언어와 컴퓨터  ...         20160520
# 998                                         수학 그리고 컴퓨터  ...         20130901
# 999                   우정사업본부 지방우정청 9급 계리직 심화문제특강 컴퓨터일반  ...         20151020
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## 네이버 영화 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re
client_id = "WowZ7jVFhwfw9UZwT1jr"
client_secret = "nKIhVXKvZY"

query = urllib.parse.quote(input("검색질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

movie_df = pd.DataFrame(columns=("Title", "Link", "Image", "Subtitle", "Publication Date", "Director", "Actor", "User Rating"))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/movie?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        image = items[item_index]['image']
        subtitle = items[item_index]['subtitle']
        pub_date = items[item_index]['pubDate']
        director = items[item_index]['director']
        actor = items[item_index]['actor']
        user_rating = items[item_index]['userRating']
        
        movie_df.loc[idx] = [title, link, image, subtitle, pub_date, director, actor, user_rating]
        idx +=1
  else:
      print("Error Code:" + rescode)

movie_df
# Out:
# 검색질의: 아이언맨
#                    Title  ... User Rating
# 0        엘론 머스크: 리얼 아이언맨  ...        0.00
# 1                   아이언맨  ...        4.95
# 2     아이언맨 &amp; 캡틴 아메리카  ...        9.00
# 3                 아이언맨 3  ...        8.86
# 4    아이언 맨: 라이즈 오브 테크노보어  ...        3.28
# ..                   ...  ...         ...
# 125           인빈서블 아이언 맨  ...        7.24
# 126     특수공작원 아이언맨 - 시리즈  ...        7.63
# 127           특수공작원 아이언맨  ...        9.00
# 128                아이언 맨  ...        5.37
# 129                아이언 맨  ...        7.54
#
# [130 rows x 8 columns]

# %% [markdown]
# ## 네이버 쇼핑 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re
client_id = "WowZ7jVFhwfw9UZwT1jr"
client_secret = "nKIhVXKvZY"

query = urllib.parse.quote(input("검색질의: "))
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

shop_df = pd.DataFrame(columns=("Title", "Link", "Image", "Low Price", "High Price", "Mall Name", "Product ID", "Product Type", "Maker", "Brand"))

for start_index in range(start, end, display):

  url = "https://openapi.naver.com/v1/search/shop?query=" + query \
        + "&display=" + str(display) \
        + "&start=" + str(start_index) \
        + "&sort=" + sort

  request = urllib.request.Request(url)
  request.add_header("X-Naver-Client-Id",client_id)
  request.add_header("X-Naver-Client-Secret",client_secret)
  response = urllib.request.urlopen(request)
  rescode = response.getcode()
  if(rescode==200):
      response_body = response.read()
      response_dict = json.loads(response_body.decode('utf-8'))
      items = response_dict['items']
      for item_index in range(0, len(items)):
        remove_tag = re.compile('<.*?>')
        title = re.sub(remove_tag, '', items[item_index]['title'])
        link = items[item_index]['link']
        lprice = items[item_index]['lprice']
        hprice = items[item_index]['hprice']
        mallName = items[item_index]['mallName']
        product_id = items[item_index]['productId']
        product_type = items[item_index]['productType']
        maker = items[item_index]['maker']
        brand = items[item_index]['brand']
        shop_df.loc[idx] = [title, link, image, lprice, hprice, mallName, product_id, product_type, maker, brand]
        idx +=1
  else:
      print("Error Code:" + rescode)

shop_df
# Out:
# 검색질의: 컴퓨터
#                                                Title  ...   Brand
# 0            프리미엄 게이밍 조립컴퓨터 배틀그라운드 오버워치 배그 본체 사무용 견적  ...    마루PC
# 1                   Apple 아이맥 27형 2019년형 (MRQY2KH/A)  ...   Apple
# 2                  아싸컴 프리미엄 게이밍 i5-9400F + 외장형 그래픽카드  ...     아싸컴
# 3                                    배틀그라운드 오버워치조립PC  ...
# 4    10세대PC i5-10400 i7-10700게이밍 조립컴퓨터 배틀그라운드 사무용노마드  ...  대한컴퓨터샵
# ..                                               ...  ...     ...
# 995            애즈락 DeskMini 310 i3-8100 NVMe M.2 에즈윈  ...     애즈락
# 996                   DELL 인스피론 3671 DNDT3671-0004KR  ...    인스피론
# 997                                LG전자 22V270-LA20K  ...    LG전자
# 998                   레노버 싱크센터 M720q Tiny-10T7S1AS00  ...    싱크센터
# 999                                   주연테크 엣지2 S94NW  ...    주연테크
#
# [1000 rows x 10 columns]
